# %%
import pandas as pd
import matplotlib.pyplot as plt
import lib.Charts as chart

# %%
data_frame = pd.read_csv("./data/prime.csv", encoding="shift-jis")
sizes = data_frame["33業種区分"].value_counts()
labels = data_frame["33業種区分"].value_counts().index
chart.get_pie_ratio(labels, sizes, "Prime")
# Out:
# Prime

# %%
data_frame = pd.read_csv("./data/standard.csv", encoding="shift-jis")
sizes = data_frame["33業種区分"].value_counts()
labels = data_frame["33業種区分"].value_counts().index
chart.get_pie_ratio(labels, sizes, "standard")
# Out:
# standard
